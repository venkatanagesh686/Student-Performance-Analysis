# %%
import pandas as pd

data = pd.read_csv("C:/Users/venka/Downloads/archive (3)/StudentsPerformance.csv")

print(data.head(100))
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# ..     ...            ...                         ...           ...
# 95    male        group C          associate's degree  free/reduced
# 96    male        group B            some high school      standard
# 97  female        group E                some college      standard
# 98  female        group D                some college  free/reduced
# 99  female        group D           bachelor's degree      standard
#
#    test preparation course  math score  reading score  writing score
# 0                     none          72             72             74
# ...

# %%
data.shape
# Out:
# (1000, 8)

# %%
print(data["math score"].mean())
print(data["reading score"].mean())
print(data["writing score"].mean())
# Out:
# 66.089
# 69.169
# 68.054

# %%
import matplotlib.pyplot as plt

data["math score"].hist()
plt.title("Math Score Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt

data["reading score"].hist()
plt.title("reading Score Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt

data["writing score"].hist()
plt.title("writing Score Distribution")
plt.show()
